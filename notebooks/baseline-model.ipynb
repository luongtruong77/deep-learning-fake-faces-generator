# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import os

from IPython.display import Image

# %%
generator = keras.models.load_model('../models/generator_1epoch.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
latent_dim = 128
random_latent_vectors = tf.random.normal(shape=(10, latent_dim))
generated_images = generator(random_latent_vectors)
generated_images *= 255
generated_images.numpy()
plt.figure(figsize=(12,6))
for i in range(10):
  plt.subplot(2, 5, i+1)
  plt.imshow((generated_images[i] / 255).numpy())
  plt.axis('off')
#plt.savefig('gdrive/MyDrive/saved_files/sample_%d.png' % (2))

# %%
latent_dim = 128
random_latent_vectors = tf.random.normal(shape=(10, latent_dim))
generated_images = generator(random_latent_vectors)
plt.figure(figsize=(4,4))
plt.imshow(generated_images[0].numpy())
plt.axis('off')
plt.show()
#plt.savefig('gdrive/MyDrive/saved_files/sample_%d.png' % (2))

# %%
generator_10 = keras.models.load_model('../models/generator_10epochs.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
latent_dim = 128
random_latent_vectors = tf.random.normal(shape=(10, latent_dim))
generated_images = generator_10(random_latent_vectors)
plt.figure(figsize=(4,4))
plt.imshow(generated_images[0].numpy())
plt.axis('off')
plt.show()
#plt.savefig('gdrive/MyDrive/saved_files/sample_%d.png' % (2))

# %%
latent_dim = 128
random_latent_vectors = tf.random.normal(shape=(10, latent_dim))
generated_images = generator_10(random_latent_vectors)
generated_images *= 255
generated_images.numpy()
plt.figure(figsize=(12,6))
for i in range(10):
  plt.subplot(2, 5, i+1)
  plt.imshow((generated_images[i] / 255).numpy())
  plt.axis('off')
#plt.savefig('gdrive/MyDrive/saved_files/sample_%d.png' % (2))

# %%
generator_10_20k = keras.models.load_model('../models/generator_10epochs_20k.h5')
latent_dim = 128
random_latent_vectors = tf.random.normal(shape=(10, latent_dim))
generated_images = generator_10_20k(random_latent_vectors)
plt.figure(figsize=(4,4))
plt.imshow(generated_images[0].numpy())
plt.axis('off')
plt.show()
#plt.savefig('gdrive/MyDrive/saved_files/sample_%d.png' % (2))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
latent_dim = 128
random_latent_vectors = tf.random.normal(shape=(10, latent_dim))
generated_images = generator_10_20k(random_latent_vectors)
generated_images *= 255
generated_images.numpy()
plt.figure(figsize=(12,6))
for i in range(10):
  plt.subplot(2, 5, i+1)
  plt.imshow((generated_images[i] / 255).numpy())
  plt.axis('off')
#plt.savefig('gdrive/MyDrive/saved_files/sample_%d.png' % (2))
